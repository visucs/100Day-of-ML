# %% [markdown]
# <a href="https://colab.research.google.com/github/visucs/100Day-of-ML/blob/main/installation_class_12Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#class 12 installation anaconda and kaggle and colab

# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/aug_train.csv')

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d wobotintelligence/face-mask-detection-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/wobotintelligence/face-mask-detection-dataset
# License(s): CC0-1.0
# ...
#  87% 2.18G/2.50G [00:26<00:02, 152MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('face-mask-detection-dataset.zip','r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
